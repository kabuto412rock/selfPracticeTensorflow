# %% [markdown]
# # Gui

# %%
''' 功能：相片視窗界面。
    提供一個可以 開啟檔案的按鈕，點選後跳出開檔視窗，選定的圖片印出來。

'''
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
from collections import defaultdict
from io import StringIO
from matplotlib import pyplot as plt

import tkinter as tk
from tkinter.filedialog import askopenfilename
from PIL import Image, ImageTk
import numpy as np
import cv2

print('成功import12')
# This is needed to display the images.
# %matplotlib inline

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
print('env ok')

from utils import label_map_util
# 內含有將物件偵測結果視覺化的API
from utils import visualization_utils as vis_util
print('ok')

# What model to download.
# TF已經訓練好的模型名稱
# 應該是最快的Model
MODEL_NAME = 'ssd_mobilenet_v1_coco_11_06_2017'

# 中等速度的Model
# 第一張圖處理14.156，後面的圖處理每張大約花4~5秒的時間。
# MODEL_NAME = 'rfcn_resnet101_coco_11_06_2017'

# # 賭賭看改用這個比較慢的模型，可以跑但是很慢，這是最慢的模型一張圖要花40多秒，最猛的模型
# MODEL_NAME = 'faster_rcnn_inception_resnet_v2_atrous_coco_11_06_2017'

# TF已經訓練好的模型檔案(本身是一個tar.gz的壓縮檔)
MODEL_FILE = MODEL_NAME + '.tar.gz'

# 這個TF訓練好模型 所在網站的目錄名稱
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'

# TF實際用來做物件偵測的模型 
# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'

# 這個模型對應到的種類txt檔，內涵每個種類的索引&名稱
# 之後物件偵測得到的資訊會是索引，所以需要此文件參考名稱
# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('data', 'mscoco_label_map.pbtxt')

# 預設模型種類數量 為90種
NUM_CLASSES = 90
print('Model preparation is ok...')

## Download Model (如果之前下載過模組，那該這個區塊可以不用再執行一次)

# opener = urllib.request.URLopener()
# # opener.retrieve(下載的檔案來源, 下載的檔案存放的本地位址)
# opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)

# tar_file = tarfile.open(MODEL_FILE)
# for file in tar_file.getmembers():
#     file_name = os.path.basename(file.name)
#     if 'frozen_inference_graph.pb' in file_name:
#         tar_file.extract(file, os.getcwd())
# print('Download Model is ok', os.getcwd())

## Load a (frozen) Tensorflow model into memory.

detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')

label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = (label_map_util.convert_label_map_to_categories(
    label_map, 
    max_num_classes=NUM_CLASSES, 
    use_display_name=True))

category_index = label_map_util.create_category_index(categories)
print(category_index)

## Helper code

def load_image_into_numpy_array(image):
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)
# Detection

import time 
IMAGE_HEAD_NAME = 'dog{}.jpg'
# For the sake of simplicity we will use only 2 images:
# image1.jpg
# image2.jpg
# If you want to test the code with your images, just add path to the images to the TEST_IMAGE_PATHS.
PATH_TO_TEST_IMAGES_DIR = 'test_images'

TEST_IMAGE_PATHS = [ os.path.join(PATH_TO_TEST_IMAGES_DIR, IMAGE_HEAD_NAME.format(i)) for i in range(0, 100) ]
# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)

# #除了看已看出有哪些物種，也能看出對應後images_obj_coordinates和image_obj_scores的索引
# images_obj_classes_indexs = []

# # 有什麼種類的物件
# images_obj_classes = []
# images_obj_coordinates = []
# images_obj_scores = []

# A組圖代表 前A_SIZE個 物件陣列索引a陣列, 圖片的物件字典, 相似分數, 物件座標
A_SIZE = 76
a_obj_indexs = []
a_obj_data = []
a_obj_coordinates = []
a_obj_scores = []

# B組圖丟入的物件
b_image_name =  os.path.join(PATH_TO_TEST_IMAGES_DIR, IMAGE_HEAD_NAME.format(A_SIZE))

# B組圖代表 第A_SIZE個 物件陣列索引a陣列, 圖片的物件字典, 相似分數, 物件座標
b_obj_indexs = []
b_obj_data = []
b_obj_coordinates = []
b_obj_scores = []


# b圖物件的直方圖串列
b_obj_hist = list()

# A組所有圖片的物件直方圖串列的串列
imgs_hist_list = list()

# b_match_a，為圖片B 跟 A組圖片們物件數比對成功串列的串列。
b_match_a = list()

def db_a_get_ready():
    #除了看已看出有哪些物種，也能看出對應後images_obj_coordinates和image_obj_scores的索引
    images_obj_classes_indexs = []

    # 有什麼種類的物件
    images_obj_classes = []
    images_obj_coordinates = []
    images_obj_scores = []
    
    
    global a_obj_indexs, a_obj_data, a_obj_coordinates, a_obj_scores
    with detection_graph.as_default():
      with tf.Session(graph=detection_graph) as sess:
        for image_path in TEST_IMAGE_PATHS:
#           tStart = time.time()
          image = Image.open(image_path)
          # the array based representation of the image will be used later in order to prepare the
          # result image with boxes and labels on it.

          image_np = load_image_into_numpy_array(image)


          # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
          image_np_expanded = np.expand_dims(image_np, axis=0)
          image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
          # Each box represents a part of the image where a particular object was detected.
          boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
          # Each score represent how level of confidence for each of the objects.
          # Score is shown on the result image, together with the class label.
          scores = detection_graph.get_tensor_by_name('detection_scores:0')
          classes = detection_graph.get_tensor_by_name('detection_classes:0')
          num_detections = detection_graph.get_tensor_by_name('num_detections:0')
          # Actual detection.
          (boxes, scores, classes, num_detections) = sess.run(
              [boxes, scores, classes, num_detections],
              feed_dict={image_tensor: image_np_expanded})

    #     # 印出每個物件的位置.分數.種類
    #       print('boxes[0]:', boxes[0])
    #       print('scores[0]:', scores[0])
    #       print('classes:', classes)
    #       print('\n\n\n')
    #       for i in range(2):
    #           print("-----------------------------------------------------")
    #       print('---------------- %s--------------' % image_path)      
    #       for i in range(2):
    #         print("-----------------------------------------------------")
          # 分數高於0.5的才可以視為相符
          obj_length = len([x for x in scores[0] if x > 0.6])
          width, height = image.size

          # 第一實驗魔改_Begin 該圖片所有的物件種類   
          all_objs = classes[0]
          ok_objs = all_objs[0:obj_length]
          objs_classes = set(ok_objs)

          # Result 1 對應原始物件索引陣列的字典(Key為類別名， Value為對應原始陣列的物件索引陣列)
          img_classes = dict()

          # newnew＠＠＠＠
          img_obj_class_indexs = dict()

          for obj_class in objs_classes:
            img_classes[category_index[obj_class]['name']] = len(np.nonzero(ok_objs == obj_class)[0])

            img_obj_class_indexs[category_index[obj_class]['name']] = np.nonzero(ok_objs == obj_class)[0]
#             print('obj_class ', category_index[obj_class]['name'], ":", np.nonzero(ok_objs == obj_class)[0])
    #         print(category_index[obj_class]['name'], ':', len(np.nonzero(ok_objs == obj_class)[0]))
    #         print('種類:', category_index[obj_class]['name'])
    #         print(np.nonzero(ok_objs == obj_class)[0], '有', len(np.nonzero(ok_objs == obj_class)[0]),'個') 

          # Result 2 原始物件的標記位置陣列[(x1, y1, x2, y2)]
          img_obj_coordinates = boxes[0][0:obj_length]

          # Result 3 原始物件的相似分數陣列
          img_obj_scores = scores[0][0:obj_length]

          # 標示每個圖片上所有的物件Visualization of the results of a detection.  
    #     # 如果要顯示圖片在ipynb，這個區塊可以取消註解 
    #       vis_util.visualize_boxes_and_labels_on_image_array(
    #           image_np,
    #           np.squeeze(boxes),
    #           np.squeeze(classes).astype(np.int32),
    #           np.squeeze(scores),
    #           category_index,
    #           use_normalized_coordinates=True,
    #           line_thickness=4)
    #       plt.figure(figsize=IMAGE_SIZE)
    #       plt.imshow(image_np)
    #       # 如果要顯示圖片在ipynb，這個區塊可以取消註解 
          # 第一實驗魔改_End
          images_obj_classes_indexs.append(img_obj_class_indexs)
          images_obj_classes.append(img_classes)
          images_obj_coordinates.append(img_obj_coordinates)
          images_obj_scores.append(img_obj_scores)
          
#           tEnd = time.time()
          cnt = len(images_obj_classes_indexs)
          if cnt % 10 == 0:
              print('已有{}個圖片建立檔案結束...'.format(cnt))
                
    # A組圖代表 前A_SIZE個 物件陣列索引a陣列, 圖片的物件字典, 相似分數, 物件座標
    a_obj_indexs = images_obj_classes_indexs[0:A_SIZE]
    a_obj_data = images_obj_classes[0:A_SIZE]
    a_obj_scores = images_obj_scores[0:A_SIZE]
    a_obj_coordinates = images_obj_coordinates[0:A_SIZE]
    print('db_a_get_ready結束')
    print('結束')
    
def db_b_get_ready(image_path):
    global b_obj_indexs, b_obj_data, b_obj_coordinates, b_obj_scores
    b_obj_coordinates = []
    b_obj_data = []
    b_obj_scores = []
    
    with detection_graph.as_default():
      with tf.Session(graph=detection_graph) as sess:
          image = Image.open(image_path)
          # the array based representation of the image will be used later in order to prepare the
          # result image with boxes and labels on it.

          image_np = load_image_into_numpy_array(image)
        

          # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
          image_np_expanded = np.expand_dims(image_np, axis=0)
          image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
          # Each box represents a part of the image where a particular object was detected.
          boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
          # Each score represent how level of confidence for each of the objects.
          # Score is shown on the result image, together with the class label.
          scores = detection_graph.get_tensor_by_name('detection_scores:0')
          classes = detection_graph.get_tensor_by_name('detection_classes:0')
          num_detections = detection_graph.get_tensor_by_name('num_detections:0')
          # Actual detection.
          (boxes, scores, classes, num_detections) = sess.run(
              [boxes, scores, classes, num_detections],
              feed_dict={image_tensor: image_np_expanded})
          print('b_get_ready() 287')
    #     # 印出每個物件的位置.分數.種類
    #       print('boxes[0]:', boxes[0])
    #       print('scores[0]:', scores[0])
    #       print('classes:', classes)
    #       print('\n\n\n')
    #       for i in range(2):
    #           print("-----------------------------------------------------")
    #       print('---------------- %s--------------' % image_path)      
    #       for i in range(2):
    #         print("-----------------------------------------------------")
          # 分數高於0.5的才可以視為相符
          obj_length = len([x for x in scores[0] if x > 0.6])
          width, height = image.size
          print('b_get_ready() 301')
          # 第一實驗魔改_Begin 該圖片所有的物件種類   
          all_objs = classes[0]
          ok_objs = all_objs[0:obj_length]
          objs_classes = set(ok_objs)

          # Result 1 對應原始物件索引陣列的字典(Key為類別名， Value為對應原始陣列的物件索引陣列)
          img_classes = dict()
          print('b_get_ready() 309')
          # newnew＠＠＠＠
          img_obj_class_indexs = dict()
          print('b_get_ready() 312')
          for obj_class in objs_classes:
            img_classes[category_index[obj_class]['name']] = len(np.nonzero(ok_objs == obj_class)[0])

            img_obj_class_indexs[category_index[obj_class]['name']] = np.nonzero(ok_objs == obj_class)[0]
#             print('obj_class ', category_index[obj_class]['name'], ":", np.nonzero(ok_objs == obj_class)[0])
    #         print(category_index[obj_class]['name'], ':', len(np.nonzero(ok_objs == obj_class)[0]))
    #         print('種類:', category_index[obj_class]['name'])
    #         print(np.nonzero(ok_objs == obj_class)[0], '有', len(np.nonzero(ok_objs == obj_class)[0]),'個') 
          print('b_get_ready() 321')
          # Result 2 原始物件的標記位置陣列[(x1, y1, x2, y2)]
          img_obj_coordinates = boxes[0][0:obj_length]
          print('b_get_ready() 324')
          # Result 3 原始物件的相似分數陣列
          img_obj_scores = scores[0][0:obj_length]
          print('b_get_ready() 327')
          # 標示每個圖片上所有的物件Visualization of the results of a detection.  
    #     # 如果要顯示圖片在ipynb，這個區塊可以取消註解 
    #       vis_util.visualize_boxes_and_labels_on_image_array(
    #           image_np,
    #           np.squeeze(boxes),
    #           np.squeeze(classes).astype(np.int32),
    #           np.squeeze(scores),
    #           category_index,
    #           use_normalized_coordinates=True,
    #           line_thickness=4)
    #       plt.figure(figsize=IMAGE_SIZE)
    #       plt.imshow(image_np)
    #       # 如果要顯示圖片在ipynb，這個區塊可以取消註解 
          # 第一實驗魔改_End
          print('@@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@')
          b_obj_indexs = img_obj_class_indexs
        
          print('b_obj_indexs:', b_obj_indexs)
          b_obj_data.append(img_classes)
          print('b_obj_data:', b_obj_data)
          b_obj_coordinates.append(img_obj_coordinates)
          print('b_obj_coordinates:', b_obj_coordinates)
          b_obj_scores.append(img_obj_scores)
          print('b_obj_scores:', b_obj_scores)
          print('b_get_ready() 346')
#           tEnd = time.time()
          cnt = len(b_obj_scores)
          print('已有{}個圖片建立檔案結束...'.format(cnt))
    b_obj_coordinates = b_obj_coordinates[0]
    print('db_b_get_ready結束')
    


# 實驗4
# 此為一對多的實驗
# 讀取一個圖片，從20張圖片挑出符合物件條件&色彩特徵相似的的圖片。

def match_a_b():
    global imgs_hist_list, b_obj_hist
    global b_match_a
    
    # 每次執行match_a_b()都會初始化 底下這三個串列
    # b圖物件的直方圖串列
    b_obj_hist = list()
    
    # A組所有圖片的物件直方圖串列的串列
    imgs_hist_list = list()

    # b_match_a，為圖片B 跟 A組圖片們物件數比對成功串列的串列。
    b_match_a = list()

    tStart = time.time()

    b_objs = b_obj_data[0]
    for a_key, a_objs in enumerate(a_obj_data):
        if b_objs == a_objs:
            b_match_a.append(a_key)
    print('b圖跟 以下索引的A組圖 配對成功:')
    print(b_match_a)



    print('\n\n B組....')
    print('------ 秀出B圖的物件字典 ------')
    print(b_obj_data)    
    # 秀出B圖的 物件相似分數陣列
    print('------ 秀出B圖的 物件相似分數陣列 ------')
    for b_key, b_scores in enumerate(b_obj_scores):
        print('b_obj_scores[{}] = {}'.format(b_key, b_scores))
    # 秀出B圖的 物件座標陣列
    print('------ 秀出B圖的 物件座標陣列 ------')
    for b_key, b_coordinates in enumerate(b_obj_coordinates):
        print('b_obj_coordinates[{}] = {}'.format(b_key, b_coordinates))

    # print('\n\nＡ組....')

    # # 秀出Ａ組每張圖的 物件相似分數陣列
    # for a_key, a_scores in enumerate(a_obj_scores):
    #     print('a_obj_scores[{}] = {}'.format(a_key, a_scores))

    # # 秀出Ａ組每張圖的 物件座標陣列
    # for a_key, a_coordinates in enumerate(a_obj_coordinates):
    #     print('a_obj_coordinates[{}] = {}'.format(a_key, a_coordinates))

    tEnd = time.time()
    print('\n第二實驗_比對結束:', tEnd - tStart)

    print('b_image讀取name')

    b_image = cv2.imread(b_image_name)

    height, width = b_image.shape[0:2]
    print('width:', width)
    print('height', height)

#     # # 展示B圖片
#     plt.figure(figsize=IMAGE_SIZE)
#     plt.imshow(cv2.cvtColor(b_image, cv2.COLOR_BGR2RGB))


    #  迭代 b圖片的所有物件
    for b_key, b_coordinates in enumerate(b_obj_coordinates):
        y1 = int(b_coordinates[1] * height)
        y2 = int(b_coordinates[3] * height)
        x1 = int(b_coordinates[0] * width)
        x2 = int(b_coordinates[2] * width)
        print(x1, y1, x2, y2)
        obj_img = b_image[y1:y2, x1:x2]

#         # 展示B圖物件的截取圖
#         plt.figure(figsize=IMAGE_SIZE)
#         plt.imshow(cv2.cvtColor(obj_img, cv2.COLOR_BGR2RGB))

        # 產生B圖物件的直方圖
        obj_hsv = cv2.cvtColor(obj_img, cv2.COLOR_BGR2HSV)
        obj_hist = cv2.calcHist([obj_hsv], [0, 1], None, [30, 25], [0,180,0,256])

    # #     # 展示B圖物件的直方圖
    #     plt.figure(figsize=IMAGE_SIZE)
    #     plt.imshow(obj_hist)

        # 添加B圖物件的直方圖到 b_obj_hist裡面。
        b_obj_hist.append(obj_hist)



    print('-=====================================')
    print('-=====================================')
    print('-=====================================')
    print('-=====================================')


    for a_img_index in b_match_a:
        # a組的單張圖片＿圖檔名稱
        a_imag_name =  os.path.join(PATH_TO_TEST_IMAGES_DIR, IMAGE_HEAD_NAME.format(a_img_index))

        # a組的單張圖片
        a_image = cv2.imread(a_imag_name)
        height, width = a_image.shape[0:2]

        # 存放 a組單張圖片的所有物件直方圖的串列
        a_obj_hist = list()

        print('a_obj_coordinates[{}]'.format(a_img_index))

        # 迭代 a組單張圖片的所有物件
        for a_key, a_coordinates in enumerate(a_obj_coordinates[a_img_index]):
            y1 = int(a_coordinates[1] * height)
            y2 = int(a_coordinates[3] * height)
            x1 = int(a_coordinates[0] * width)
            x2 = int(a_coordinates[2] * width)
            print('物件： ', x1, y1, x2, y2)
            # a組單張圖片中某個物件截圖
            obj_img = a_image[y1:y2, x1:x2]

            # 產生a組單張圖片中某個物件的直方圖
            obj_hsv = cv2.cvtColor(obj_img, cv2.COLOR_BGR2HSV)
            obj_hist = cv2.calcHist([obj_hsv], [0, 1], None, [30, 25], [0,180,0,256])

            # 將 某個物件的直方圖 添加到 a_obj_hist
            a_obj_hist.append(obj_hist)

            # 將第a_img_index張圖的a_obj_hist 添加到 imgs_hist_list
        imgs_hist_list.append(a_obj_hist)
    #         # 展示 a組單張圖片中某個物件的直方圖
    #         plt.figure()
    #         plt.imshow(cv2.cvtColor(a_image, cv2.COLOR_BGR2RGB))

    tEnd = time.time()
    print('該區塊花費時間:', tEnd - tStart)
    

def final_compare(): 
    imgs_scores = list()
    global a_obj_indexs, b_obj_indexs
    global imgs_hist_list, b_match_a, b_obj_hist
    for a_index, a_objs in enumerate(imgs_hist_list):
        compare_sum = 0
        print('\n比對a組的 第{}張圖片'.format(b_match_a[a_index]))
        print('b組：')

        #圖片
        img_score = 0

        # 在種類b_class_key的A組某個圖跟B組圖比較
        all_class_high_scores = list()

        for b_class_key in b_obj_indexs.keys():
            print('先拿A組某地{}張圖片跟b組，先比物件{}的直方圖'.format(b_match_a[a_index], b_class_key))
            print('a_obj_indexs:', a_obj_indexs)
            print('b_obj_indexs:', b_obj_indexs)
            print('a_index = {}, b_class_key = {}, b_match_a = {}, '.format(a_index, b_class_key, b_match_a))
            print('b_match_a[{}] ={}'.format(a_index, b_match_a[a_index]))
            print('b_obj_indexs[b_class_key]={}', b_obj_indexs[b_class_key])
            print('a_obj_indexs[b_match_a[a_index]] = {}'.format( a_obj_indexs[b_match_a[a_index]]) )
            
            a_obj_index = a_obj_indexs[b_match_a[a_index]][b_class_key]
            b_obj_index = b_obj_indexs[b_class_key]
            print('a_obj_index, ', a_obj_index)
            print('b_obj_index, ', b_obj_index)
            a_filter_class_hists = [a_objs[inx] for inx in a_obj_index]
            b_filter_class_hists = [b_obj_hist[inx] for inx in b_obj_index] 


            class_high_scores = list()
            # N類別的a圖的所有物件 
            for a_h in a_filter_class_hists:

                ab_compare_scores = list()

                # N類別的a圖的單個物件 跟 N類別的b圖的所有物件 做比較
                for b_h in b_filter_class_hists:

                    # 計算彼此直方圖相似度，並加入串列中。
                    ab_compare_score = cv2.compareHist(a_h, b_h, cv2.HISTCMP_CORREL)
                    ab_compare_scores.append(ab_compare_score)
                    print('ab_compare_score =', ab_compare_score)
                # N類別a圖單個物件跟跟 N類別的b圖的所有物件，將最高的相似度添加到 class_high_scores
                class_high_scores.append(max(ab_compare_scores))
                print('max(ab_compare_scores)=', max(ab_compare_scores))

            # 將某一個N類別a組圖所有物件跟b圖所有物件 把所有物件最高分數取平均，獲得N類別的相似度
            N_class_high_score = sum(class_high_scores)/ len(class_high_scores) 
            print('N_class_high_score =', class_high_scores)

            #並將他添加到 所有類別分數串列底下
            all_class_high_scores.append(N_class_high_score)

        # 所以一張圖片的分數 = 一張圖片所有類別分數的平均
        img_score = sum(all_class_high_scores) / len(all_class_high_scores)
        print('img_score =', img_score)

        # 將該圖片的分數 添加到 所有圖片的分數
        imgs_scores.append(img_score)
    print('img_scores', imgs_scores)

    if not imgs_scores:
        print('沒有相符的圖片')
        none_img_name = os.path.join(PATH_TO_TEST_IMAGES_DIR, 'None.png')
        none_img = cv2.imread(none_img_name)
        return none_img
    else:
        max_score = max(imgs_scores)
        max_index = imgs_scores.index(max_score)

        # 結果
        print('a組第{}張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達{:f}%'.format(b_match_a[max_index], max_score*100))
        similar_img_name = os.path.join(PATH_TO_TEST_IMAGES_DIR, IMAGE_HEAD_NAME.format(b_match_a[max_index]))
        similar_img = cv2.imread(similar_img_name)
        return similar_img
#         plt.figure()
#         plt.imshow(cv2.cvtColor(similar_img, cv2.COLOR_BGR2RGB))
# Out:
# 成功import12
# env ok
# ok
# Model preparation is ok...
# {1: {'id': 1, 'name': 'person'}, 2: {'id': 2, 'name': 'bicycle'}, 3: {'id': 3, 'name': 'car'}, 4: {'id': 4, 'name': 'motorcycle'}, 5: {'id': 5, 'name': 'airplane'}, 6: {'id': 6, 'name': 'bus'}, 7: {'id': 7, 'name': 'train'}, 8: {'id': 8, 'name': 'truck'}, 9: {'id': 9, 'name': 'boat'}, 10: {'id': 10, 'name': 'traffic light'}, 11: {'id': 11, 'name': 'fire hydrant'}, 13: {'id': 13, 'name': 'stop sign'}, 14: {'id': 14, 'name': 'parking meter'}, 15: {'id': 15, 'name': 'bench'}, 16: {'id': 16, 'name': 'bird'}, 17: {'id': 17, 'name': 'cat'}, 18: {'id': 18, 'name': 'dog'}, 19: {'id': 19, 'name': 'horse'}, 20: {'id': 20, 'name': 'sheep'}, 21: {'id': 21, 'name': 'cow'}, 22: {'id': 22, 'name': 'elephant'}, 23: {'id': 23, 'name': 'bear'}, 24: {'id': 24, 'name': 'zebra'}, 25: {'id': 25, 'name': 'giraffe'}, 27: {'id': 27, 'name': 'backpack'}, 28: {'id': 28, 'name': 'umbrella'}, 31: {'id': 31, 'name': 'handbag'}, 32: {'id': 32, 'name': 'tie'}, 33: {'id': 33, 'name': 'suitcase'}, 34: {'id': 34, 'name': 'frisbee'}, 35: {'id': 35, 'name': 'skis'}, 36: {'id': 36, 'name': 'snowboard'}, 37: {'id': 37, 'name': 'sports ball'}, 38: {'id': 38, 'name': 'kite'}, 39: {'id': 39, 'name': 'baseball bat'}, 40: {'id': 40, 'name': 'baseball glove'}, 41: {'id': 41, 'name': 'skateboard'}, 42: {'id': 42, 'name': 'surfboard'}, 43: {'id': 43, 'name': 'tennis racket'}, 44: {'id': 44, 'name': 'bottle'}, 46: {'id': 46, 'name': 'wine glass'}, 47: {'id': 47, 'name': 'cup'}, 48: {'id': 48, 'name': 'fork'}, 49: {'id': 49, 'name': 'knife'}, 50: {'id': 50, 'name': 'spoon'}, 51: {'id': 51, 'name': 'bowl'}, 52: {'id': 52, 'name': 'banana'}, 53: {'id': 53, 'name': 'apple'}, 54: {'id': 54, 'name': 'sandwich'}, 55: {'id': 55, 'name': 'orange'}, 56: {'id': 56, 'name': 'broccoli'}, 57: {'id': 57, 'name': 'carrot'}, 58: {'id': 58, 'name': 'hot dog'}, 59: {'id': 59, 'name': 'pizza'}, 60: {'id': 60, 'name': 'donut'}, 61: {'id': 61, 'name': 'cake'}, 62: {'id': 62, 'name': 'chair'}, 63: {'id': 63, 'name': 'couch'}, 64: {'id': 64, 'name': 'potted plant'}, 65: {'id': 65, 'name': 'bed'}, 67: {'id': 67, 'name': 'dining table'}, 70: {'id': 70, 'name': 'toilet'}, 72: {'id': 72, 'name': 'tv'}, 73: {'id': 73, 'name': 'laptop'}, 74: {'id': 74, 'name': 'mouse'}, 75: {'id': 75, 'name': 'remote'}, 76: {'id': 76, 'name': 'keyboard'}, 77: {'id': 77, 'name': 'cell phone'}, 78: {'id': 78, 'name': 'microwave'}, 79: {'id': 79, 'name': 'oven'}, 80: {'id': 80, 'name': 'toaster'}, 81: {'id': 81, 'name': 'sink'}, 82: {'id': 82, 'name': 'refrigerator'}, 84: {'id': 84, 'name': 'book'}, 85: {'id': 85, 'name': 'clock'}, 86: {'id': 86, 'name': 'vase'}, 87: {'id': 87, 'name': 'scissors'}, 88: {'id': 88, 'name': 'teddy bear'}, 89: {'id': 89, 'name': 'hair drier'}, 90: {'id': 90, 'name': 'toothbrush'}}

# %%
if __name__ == '__main__':
    # 預先載入資料庫的作出分析。
    db_a_get_ready()
    
    # 視窗介面
    window = tk.Tk()
    window.title('my window')
    window.geometry('800x600')

    lmain = tk.Label(window)
    lmain.pack()

    result_label = tk.Label(window)
    result_label.pack()

    # lmain = tk.Canvas(window, bg='blue', height=100, width=200)
    # lmain.pack()

    # 當按下開啟圖片，會跳出讀檔視窗
    def open_file():
        print('{}x{}'.format(window.winfo_width(), window.winfo_height()))
        name = askopenfilename(filetypes =(("JPG File", "*.jpg"), ("PNG File","*.png")), title = "Choose a image.")
        # 測試圖片是否存在
        try:
            with open(name, 'r') as ChooseFile:
                window.title('圖片{}存在'.format(name))
                img = cv2.imread(name)
                img = cv2.resize(img, (200, 200))
                cv2image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                global lmain
                print('hello', lmain.winfo_height())
                img = Image.fromarray(cv2image)
                imgtk = ImageTk.PhotoImage(image=img)
                lmain.imgtk = imgtk
                lmain.configure(image=imgtk)
                print('開始分析囉')
                # 開始分析囉...
                db_b_get_ready(name)

                # 將db_b_get_ready()和db_a_get_ready()得到的物件字典結果進行比較，找出相同的
                match_a_b()
                print('b_match_a: ', b_match_a)
                print()
                # 最終比較會回傳出最相似的圖片，或者回傳None
                similar_img = final_compare()
                if similar_img is None:
                    print('分析結果，完全沒有相似的圖片')
                else:
                    similar_img = cv2.resize(similar_img, (200, 200))
                    similar_img = cv2.cvtColor(similar_img, cv2.COLOR_BGR2RGB)

                    img = Image.fromarray(similar_img)
                    imgtk = ImageTk.PhotoImage(image=img)
                    global result_label
                    result_label.imgtk = imgtk
                    result_label.configure(image=imgtk)

    #             panelA = Label(window, image=image)
    #             panelA.image = image
    #             panelA.pack(side="left", padx=10, pady=10)

    #             cv2.imshow('h', img)
    #             cv2.waitKey(0)
    #             cv2.destroyAllWindows()
        except:
            window.title("圖片不存在")

    # 建立一個按鈕，負責開啟檔案
    button = tk.Button(window, 
        text='開啟檔案', 
        width=15, height=2, 
        command=open_file)

    button.pack()

    # 視窗的主迴圈
    window.mainloop()
# Out:
# 已有10個圖片建立檔案結束...
# 已有20個圖片建立檔案結束...
# 已有30個圖片建立檔案結束...
# 已有40個圖片建立檔案結束...
# 已有50個圖片建立檔案結束...
# 已有60個圖片建立檔案結束...
# 已有70個圖片建立檔案結束...
# 已有80個圖片建立檔案結束...
# 已有90個圖片建立檔案結束...
# 已有100個圖片建立檔案結束...
# db_a_get_ready結束
# 結束
# 800x600
# hello 22
# 開始分析囉
# b_get_ready() 287
# b_get_ready() 301
# b_get_ready() 309
# b_get_ready() 312
# b_get_ready() 321
# b_get_ready() 324
# b_get_ready() 327
# @@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@
# b_obj_indexs: {'dog': array([0, 1])}
# b_obj_data: [{'dog': 2}]
# b_obj_coordinates: [array([[ 0.21029636,  0.02219117,  0.89699912,  0.5875048 ],
#        [ 0.19806361,  0.04969934,  0.94558215,  0.85438836]], dtype=float32)]
# b_obj_scores: [array([ 0.90391338,  0.65784377], dtype=float32)]
# b_get_ready() 346
# 已有1個圖片建立檔案結束...
# db_b_get_ready結束
# b圖跟 以下索引的A組圖 配對成功:
# [17, 75]
#
#
#  B組....
# ------ 秀出B圖的物件字典 ------
# [{'dog': 2}]
# ------ 秀出B圖的 物件相似分數陣列 ------
# b_obj_scores[0] = [ 0.90391338  0.65784377]
# ------ 秀出B圖的 物件座標陣列 ------
# b_obj_coordinates[0] = [ 0.21029636  0.02219117  0.89699912  0.5875048 ]
# b_obj_coordinates[1] = [ 0.19806361  0.04969934  0.94558215  0.85438836]
#
# 第二實驗_比對結束: 0.001271963119506836
# b_image讀取name
# width: 450
# height 374
# 94 8 403 219
# 89 18 425 319
# -=====================================
# -=====================================
# -=====================================
# -=====================================
# a_obj_coordinates[17]
# 物件：  120 110 456 333
# 物件：  71 38 199 204
# a_obj_coordinates[75]
# 物件：  94 8 403 219
# 物件：  89 18 425 319
# 該區塊花費時間: 0.031221866607666016
# b_match_a:  [17, 75]
#
#
# 比對a組的 第17張圖片
# b組：
# 先拿A組某地17張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([0, 1])}
# a_index = 0, b_class_key = dog, b_match_a = [17, 75],
# b_match_a[0] =17
# b_obj_indexs[b_class_key]={} [0 1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0, 1])}
# a_obj_index,  [0 1]
# b_obj_index,  [0 1]
# ab_compare_score = 0.06340524122096082
# ab_compare_score = 0.04323979547167614
# max(ab_compare_scores)= 0.06340524122096082
# ab_compare_score = 0.056489340829346424
# ab_compare_score = 0.030866958048778658
# max(ab_compare_scores)= 0.056489340829346424
# N_class_high_score = [0.06340524122096082, 0.056489340829346424]
# img_score = 0.05994729102515362
#
# 比對a組的 第75張圖片
# b組：
# 先拿A組某地75張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([0, 1])}
# a_index = 1, b_class_key = dog, b_match_a = [17, 75],
# b_match_a[1] =75
# b_obj_indexs[b_class_key]={} [0 1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0, 1])}
# a_obj_index,  [0 1]
# b_obj_index,  [0 1]
# ab_compare_score = 1.0
# ab_compare_score = 0.9006423228737013
# max(ab_compare_scores)= 1.0
# ab_compare_score = 0.9006423228737013
# ab_compare_score = 1.0
# max(ab_compare_scores)= 1.0
# N_class_high_score = [1.0, 1.0]
# img_score = 1.0
# img_scores [0.05994729102515362, 1.0]
# a組第75張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達100.000000%
# 800x600
# hello 204
# 開始分析囉
# b_get_ready() 287
# b_get_ready() 301
# b_get_ready() 309
# b_get_ready() 312
# b_get_ready() 321
# b_get_ready() 324
# b_get_ready() 327
# @@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@
# b_obj_indexs: {'dog': array([2]), 'person': array([0, 1, 3])}
# b_obj_data: [{'dog': 1, 'person': 3}]
# b_obj_coordinates: [array([[ 0.18585455,  0.38659427,  0.92811418,  0.90256071],
#        [ 0.22223964,  0.        ,  0.85798252,  0.41475961],
#        [ 0.45379174,  0.58268255,  0.95796978,  0.98541003],
#        [ 0.09463869,  0.29416913,  0.50074345,  0.57852143]], dtype=float32)]
# b_obj_scores: [array([ 0.98695648,  0.93421835,  0.9283874 ,  0.65309864], dtype=float32)]
# b_get_ready() 346
# 已有1個圖片建立檔案結束...
# db_b_get_ready結束
# b圖跟 以下索引的A組圖 配對成功:
# [4]
#
#
#  B組....
# ------ 秀出B圖的物件字典 ------
# [{'dog': 1, 'person': 3}]
# ------ 秀出B圖的 物件相似分數陣列 ------
# b_obj_scores[0] = [ 0.98695648  0.93421835  0.9283874   0.65309864]
# ------ 秀出B圖的 物件座標陣列 ------
# b_obj_coordinates[0] = [ 0.18585455  0.38659427  0.92811418  0.90256071]
# b_obj_coordinates[1] = [ 0.22223964  0.          0.85798252  0.41475961]
# b_obj_coordinates[2] = [ 0.45379174  0.58268255  0.95796978  0.98541003]
# b_obj_coordinates[3] = [ 0.09463869  0.29416913  0.50074345  0.57852143]
#
# 第二實驗_比對結束: 0.0027670860290527344
# b_image讀取name
# width: 450
# height 374
# 83 144 417 337
# 100 0 386 155
# 204 217 431 368
# 42 110 225 216
# -=====================================
# -=====================================
# -=====================================
# -=====================================
# a_obj_coordinates[4]
# 物件：  83 260 417 609
# 物件：  100 0 386 279
# 物件：  204 393 431 665
# 物件：  42 198 225 390
# 該區塊花費時間: 0.02247309684753418
# b_match_a:  [4]
#
#
# 比對a組的 第4張圖片
# b組：
# 先拿A組某地4張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([2]), 'person': array([0, 1, 3])}
# a_index = 0, b_class_key = dog, b_match_a = [4],
# b_match_a[0] =4
# b_obj_indexs[b_class_key]={} [2]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([2]), 'person': array([0, 1, 3])}
# a_obj_index,  [2]
# b_obj_index,  [2]
# ab_compare_score = 0.10710691402242153
# max(ab_compare_scores)= 0.10710691402242153
# N_class_high_score = [0.10710691402242153]
# 先拿A組某地4張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([2]), 'person': array([0, 1, 3])}
# a_index = 0, b_class_key = person, b_match_a = [4],
# b_match_a[0] =4
# b_obj_indexs[b_class_key]={} [0 1 3]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([2]), 'person': array([0, 1, 3])}
# a_obj_index,  [0 1 3]
# b_obj_index,  [0 1 3]
# ab_compare_score = 0.18713396829742876
# ab_compare_score = 0.2336149076990591
# ab_compare_score = 0.3120524193056519
# max(ab_compare_scores)= 0.3120524193056519
# ab_compare_score = 0.12308310984436263
# ab_compare_score = 0.12688927548103865
# ab_compare_score = 0.1779233618702744
# max(ab_compare_scores)= 0.1779233618702744
# ab_compare_score = 0.1992610111532869
# ab_compare_score = 0.2227826976724918
# ab_compare_score = 0.36790832923392586
# max(ab_compare_scores)= 0.36790832923392586
# N_class_high_score = [0.3120524193056519, 0.1779233618702744, 0.36790832923392586]
# img_score = 0.19653414207951947
# img_scores [0.19653414207951947]
# a組第4張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達19.653414%
# 800x600
# hello 204
# 開始分析囉
# b_get_ready() 287
# b_get_ready() 301
# b_get_ready() 309
# b_get_ready() 312
# b_get_ready() 321
# b_get_ready() 324
# b_get_ready() 327
# @@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# b_obj_data: [{'dog': 1, 'person': 1}]
# b_obj_coordinates: [array([[ 0.26534188,  0.33268201,  0.92235291,  0.81761253],
#        [ 0.56683111,  0.19742082,  0.87007391,  0.46751773]], dtype=float32)]
# b_obj_scores: [array([ 0.97969544,  0.92138743], dtype=float32)]
# b_get_ready() 346
# 已有1個圖片建立檔案結束...
# db_b_get_ready結束
# b圖跟 以下索引的A組圖 配對成功:
# [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70]
#
#
#  B組....
# ------ 秀出B圖的物件字典 ------
# [{'dog': 1, 'person': 1}]
# ------ 秀出B圖的 物件相似分數陣列 ------
# b_obj_scores[0] = [ 0.97969544  0.92138743]
# ------ 秀出B圖的 物件座標陣列 ------
# b_obj_coordinates[0] = [ 0.26534188  0.33268201  0.92235291  0.81761253]
# b_obj_coordinates[1] = [ 0.56683111  0.19742082  0.87007391  0.46751773]
#
# 第二實驗_比對結束: 0.0010039806365966797
# b_image讀取name
# width: 450
# height 374
# 119 124 415 305
# 255 73 391 174
# -=====================================
# -=====================================
# -=====================================
# -=====================================
# a_obj_coordinates[0]
# 物件：  141 266 490 654
# 物件：  301 157 462 374
# a_obj_coordinates[16]
# 物件：  63 164 353 283
# 物件：  183 0 468 218
# a_obj_coordinates[20]
# 物件：  99 42 343 228
# 物件：  79 177 352 457
# a_obj_coordinates[24]
# 物件：  151 39 324 366
# 物件：  73 105 312 415
# a_obj_coordinates[26]
# 物件：  63 177 355 329
# 物件：  233 258 375 379
# a_obj_coordinates[28]
# 物件：  235 244 440 342
# 物件：  0 108 444 284
# a_obj_coordinates[31]
# 物件：  39 99 293 411
# 物件：  2 1 301 165
# a_obj_coordinates[34]
# 物件：  4 57 425 372
# 物件：  151 170 448 434
# a_obj_coordinates[46]
# 物件：  99 25 373 195
# 物件：  5 184 498 326
# a_obj_coordinates[47]
# 物件：  133 160 432 280
# 物件：  206 56 475 183
# a_obj_coordinates[53]
# 物件：  16 43 222 173
# 物件：  129 137 226 241
# a_obj_coordinates[60]
# 物件：  61 390 273 591
# 物件：  246 334 396 596
# a_obj_coordinates[63]
# 物件：  50 123 405 198
# 物件：  245 199 385 243
# a_obj_coordinates[65]
# 物件：  41 11 362 356
# 物件：  102 249 362 490
# a_obj_coordinates[67]
# 物件：  61 32 324 478
# 物件：  26 28 329 488
# a_obj_coordinates[70]
# 物件：  5 7 429 491
# 物件：  177 237 423 493
# 該區塊花費時間: 0.12046480178833008
# b_match_a:  [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70]
#
#
# 比對a組的 第0張圖片
# b組：
# 先拿A組某地0張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 0, b_class_key = dog, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[0] =0
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [1]
# b_obj_index,  [1]
# ab_compare_score = 0.028017270876474036
# max(ab_compare_scores)= 0.028017270876474036
# N_class_high_score = [0.028017270876474036]
# 先拿A組某地0張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 0, b_class_key = person, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[0] =0
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [0]
# b_obj_index,  [0]
# ab_compare_score = 0.03176957884597757
# max(ab_compare_scores)= 0.03176957884597757
# N_class_high_score = [0.03176957884597757]
# img_score = 0.029893424861225804
#
# 比對a組的 第16張圖片
# b組：
# 先拿A組某地16張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 1, b_class_key = dog, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[1] =16
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [1]
# b_obj_index,  [1]
# ab_compare_score = 0.08591213833986525
# max(ab_compare_scores)= 0.08591213833986525
# N_class_high_score = [0.08591213833986525]
# 先拿A組某地16張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 1, b_class_key = person, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[1] =16
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [0]
# b_obj_index,  [0]
# ab_compare_score = 0.0029821975276441014
# max(ab_compare_scores)= 0.0029821975276441014
# N_class_high_score = [0.0029821975276441014]
# img_score = 0.044447167933754674
#
# 比對a組的 第20張圖片
# b組：
# 先拿A組某地20張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 2, b_class_key = dog, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[2] =20
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0]), 'person': array([1])}
# a_obj_index,  [0]
# b_obj_index,  [1]
# ab_compare_score = 0.05040085965356135
# max(ab_compare_scores)= 0.05040085965356135
# N_class_high_score = [0.05040085965356135]
# 先拿A組某地20張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 2, b_class_key = person, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[2] =20
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0]), 'person': array([1])}
# a_obj_index,  [1]
# b_obj_index,  [0]
# ab_compare_score = 0.0924830137145353
# max(ab_compare_scores)= 0.0924830137145353
# N_class_high_score = [0.0924830137145353]
# img_score = 0.07144193668404833
#
# 比對a組的 第24張圖片
# b組：
# 先拿A組某地24張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 3, b_class_key = dog, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[3] =24
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0]), 'person': array([1])}
# a_obj_index,  [0]
# b_obj_index,  [1]
# ab_compare_score = -0.014358564790853526
# max(ab_compare_scores)= -0.014358564790853526
# N_class_high_score = [-0.014358564790853526]
# 先拿A組某地24張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 3, b_class_key = person, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[3] =24
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([0]), 'person': array([1])}
# a_obj_index,  [1]
# b_obj_index,  [0]
# ab_compare_score = -0.023097417712111944
# max(ab_compare_scores)= -0.023097417712111944
# N_class_high_score = [-0.023097417712111944]
# img_score = -0.018727991251482737
#
# 比對a組的 第26張圖片
# b組：
# 先拿A組某地26張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 4, b_class_key = dog, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[4] =26
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [1]
# b_obj_index,  [1]
# ab_compare_score = 0.1313825180452758
# max(ab_compare_scores)= 0.1313825180452758
# N_class_high_score = [0.1313825180452758]
# 先拿A組某地26張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([1]), 'person': array([0])}
# a_index = 4, b_class_key = person, b_match_a = [0, 16, 20, 24, 26, 28, 31, 34, 46, 47, 53, 60, 63, 65, 67, 70],
# b_match_a[4] =26
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([1]), 'person': array([0])}
# a_obj_index,  [0]
# b_obj_index,  [0]
# ab_compare_score = 0.16039121320053065
# max(ab_compare_scores)= 0.16039121320053065
# N_class_high_score = [0.16039121320053065]
# img_score = 0.1458868656229032
#
# 比對a組的 第28張圖片
# b組：
# 先拿A組某地28張圖片跟b組，先比物件dog的直方圖
# ...
# img_scores [0.05768797015700891, 0.15848148122856712, 0.07163755977684823, 0.017355396213661858]
# a組第12張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達15.848148%
# 800x600
# hello 204
# 開始分析囉
# b_get_ready() 287
# b_get_ready() 301
# b_get_ready() 309
# b_get_ready() 312
# b_get_ready() 321
# b_get_ready() 324
# b_get_ready() 327
# @@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@
# b_obj_indexs: {'dog': array([3]), 'person': array([0, 1, 2, 4])}
# b_obj_data: [{'dog': 1, 'person': 4}]
# b_obj_coordinates: [array([[ 0.0864124 ,  0.04831608,  0.9631269 ,  0.4768948 ],
#        [ 0.07514629,  0.63331312,  0.9832989 ,  0.94887429],
#        [ 0.07872769,  0.47577474,  0.67416978,  0.67581987],
#        [ 0.62459981,  0.15084717,  1.        ,  0.65449619],
#        [ 0.1005815 ,  0.34598535,  0.69300389,  0.55501014]], dtype=float32)]
# b_obj_scores: [array([ 0.9144485 ,  0.89654076,  0.83569467,  0.82530624,  0.81332028], dtype=float32)]
# b_get_ready() 346
# 已有1個圖片建立檔案結束...
# db_b_get_ready結束
# b圖跟 以下索引的A組圖 配對成功:
# [14]
#
#
#  B組....
# ------ 秀出B圖的物件字典 ------
# [{'dog': 1, 'person': 4}]
# ------ 秀出B圖的 物件相似分數陣列 ------
# b_obj_scores[0] = [ 0.9144485   0.89654076  0.83569467  0.82530624  0.81332028]
# ------ 秀出B圖的 物件座標陣列 ------
# b_obj_coordinates[0] = [ 0.0864124   0.04831608  0.9631269   0.4768948 ]
# b_obj_coordinates[1] = [ 0.07514629  0.63331312  0.9832989   0.94887429]
# b_obj_coordinates[2] = [ 0.07872769  0.47577474  0.67416978  0.67581987]
# b_obj_coordinates[3] = [ 0.62459981  0.15084717  1.          0.65449619]
# b_obj_coordinates[4] = [ 0.1005815   0.34598535  0.69300389  0.55501014]
#
# 第二實驗_比對結束: 0.003219127655029297
# b_image讀取name
# width: 450
# height 374
# 38 18 433 178
# 33 236 442 354
# 35 177 303 252
# 281 56 450 244
# 45 129 311 207
# -=====================================
# -=====================================
# -=====================================
# -=====================================
# a_obj_coordinates[14]
# 物件：  17 11 192 116
# 物件：  15 155 196 232
# 物件：  15 116 134 165
# 物件：  124 36 200 160
# 物件：  20 84 138 135
# 該區塊花費時間: 0.018182992935180664
# b_match_a:  [14]
#
#
# 比對a組的 第14張圖片
# b組：
# 先拿A組某地14張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([3]), 'person': array([0, 1, 2, 4])}
# a_index = 0, b_class_key = dog, b_match_a = [14],
# b_match_a[0] =14
# b_obj_indexs[b_class_key]={} [3]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([3]), 'person': array([0, 1, 2, 4])}
# a_obj_index,  [3]
# b_obj_index,  [3]
# ab_compare_score = 0.02327655087096821
# max(ab_compare_scores)= 0.02327655087096821
# N_class_high_score = [0.02327655087096821]
# 先拿A組某地14張圖片跟b組，先比物件person的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'dog': array([3]), 'person': array([0, 1, 2, 4])}
# a_index = 0, b_class_key = person, b_match_a = [14],
# b_match_a[0] =14
# b_obj_indexs[b_class_key]={} [0 1 2 4]
# a_obj_indexs[b_match_a[a_index]] = {'dog': array([3]), 'person': array([0, 1, 2, 4])}
# a_obj_index,  [0 1 2 4]
# b_obj_index,  [0 1 2 4]
# ab_compare_score = 0.07221050905470056
# ab_compare_score = 0.033679455824324585
# ab_compare_score = 0.014841483258674367
# ab_compare_score = 0.043948097723281974
# max(ab_compare_scores)= 0.07221050905470056
# ab_compare_score = 0.10846378639825953
# ab_compare_score = 0.05325256134768796
# ab_compare_score = 0.02003312101193098
# ab_compare_score = 0.06123744519878481
# max(ab_compare_scores)= 0.10846378639825953
# ab_compare_score = 0.02969927987247329
# ab_compare_score = -0.012819774166410539
# ab_compare_score = -0.00952103935694823
# ab_compare_score = 0.006094459974756945
# max(ab_compare_scores)= 0.02969927987247329
# ab_compare_score = -0.013572694232331116
# ab_compare_score = -0.04199990777232277
# ab_compare_score = -0.03062970242543536
# ab_compare_score = -0.02740576039476959
# max(ab_compare_scores)= -0.013572694232331116
# N_class_high_score = [0.07221050905470056, 0.10846378639825953, 0.02969927987247329, -0.013572694232331116]
# img_score = 0.03623838557212189
# img_scores [0.03623838557212189]
# a組第14張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達3.623839%
# 800x600
# hello 204
# 開始分析囉
# b_get_ready() 287
# b_get_ready() 301
# b_get_ready() 309
# b_get_ready() 312
# b_get_ready() 321
# b_get_ready() 324
# b_get_ready() 327
# @@@@@@@@@@@@@@@@@@@@@@@@@@WWWWWWWWW@@@@@@@@@@@@@@@@@@@@@@@@
# b_obj_indexs: {'teddy bear': array([1]), 'dog': array([0])}
# b_obj_data: [{'teddy bear': 1, 'dog': 1}]
# b_obj_coordinates: [array([[ 0.1904076 ,  0.07617238,  0.76979458,  0.76597071],
#        [ 0.21365222,  0.09248573,  0.77926087,  0.78512424]], dtype=float32)]
# b_obj_scores: [array([ 0.74865961,  0.6911934 ], dtype=float32)]
# b_get_ready() 346
# 已有1個圖片建立檔案結束...
# db_b_get_ready結束
# b圖跟 以下索引的A組圖 配對成功:
# [74]
#
#
#  B組....
# ------ 秀出B圖的物件字典 ------
# [{'teddy bear': 1, 'dog': 1}]
# ------ 秀出B圖的 物件相似分數陣列 ------
# b_obj_scores[0] = [ 0.74865961  0.6911934 ]
# ------ 秀出B圖的 物件座標陣列 ------
# b_obj_coordinates[0] = [ 0.1904076   0.07617238  0.76979458  0.76597071]
# b_obj_coordinates[1] = [ 0.21365222  0.09248573  0.77926087  0.78512424]
#
# 第二實驗_比對結束: 0.0013051033020019531
# b_image讀取name
# width: 450
# height 374
# 85 28 346 286
# 96 34 350 293
# -=====================================
# -=====================================
# -=====================================
# -=====================================
# a_obj_coordinates[74]
# 物件：  60 24 246 242
# 物件：  68 29 249 248
# 該區塊花費時間: 0.014579057693481445
# b_match_a:  [74]
#
#
# 比對a組的 第74張圖片
# b組：
# 先拿A組某地74張圖片跟b組，先比物件teddy bear的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'teddy bear': array([1]), 'dog': array([0])}
# a_index = 0, b_class_key = teddy bear, b_match_a = [74],
# b_match_a[0] =74
# b_obj_indexs[b_class_key]={} [1]
# a_obj_indexs[b_match_a[a_index]] = {'teddy bear': array([1]), 'dog': array([0])}
# a_obj_index,  [1]
# b_obj_index,  [1]
# ab_compare_score = 0.1359860667231882
# max(ab_compare_scores)= 0.1359860667231882
# N_class_high_score = [0.1359860667231882]
# 先拿A組某地74張圖片跟b組，先比物件dog的直方圖
# a_obj_indexs: [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]
# b_obj_indexs: {'teddy bear': array([1]), 'dog': array([0])}
# a_index = 0, b_class_key = dog, b_match_a = [74],
# b_match_a[0] =74
# b_obj_indexs[b_class_key]={} [0]
# a_obj_indexs[b_match_a[a_index]] = {'teddy bear': array([1]), 'dog': array([0])}
# a_obj_index,  [0]
# b_obj_index,  [0]
# ab_compare_score = 0.15799822722535037
# max(ab_compare_scores)= 0.15799822722535037
# N_class_high_score = [0.15799822722535037]
# img_score = 0.14699214697426927
# img_scores [0.14699214697426927]
# a組第74張圖片是與b圖色彩特徵最相似的...，物件色彩特徵相似度高達14.699215%

# %%
print(b_obj_indexs)
print(a_obj_indexs)
# Out:
# {'teddy bear': array([1]), 'dog': array([0])}
# [{'dog': array([1]), 'person': array([0])}, {'dog': array([2]), 'car': array([3]), 'person': array([0, 1])}, {}, {'dog': array([0])}, {'dog': array([2]), 'person': array([0, 1, 3])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([3, 4]), 'person': array([0, 1, 2])}, {'person': array([0, 1, 2, 3, 4])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([3]), 'person': array([0, 1, 2, 4])}, {'dog': array([0]), 'person': array([1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0, 1])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {'bench': array([3]), 'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'cow': array([2]), 'person': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([0])}, {}, {'dog': array([0]), 'person': array([1])}, {'sheep': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0, 2]), 'person': array([1])}, {'dog': array([0]), 'chair': array([2]), 'person': array([1])}, {'person': array([0])}, {'dog': array([0])}, {}, {'teddy bear': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'couch': array([1])}, {}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {}, {'person': array([0])}, {'dog': array([0])}, {'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0]), 'tv': array([2])}, {'dog': array([1]), 'person': array([0])}, {'cow': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0])}, {'dog': array([0]), 'person': array([1])}, {'tie': array([0]), 'dog': array([1]), 'person': array([2])}, {'dog': array([0, 1, 2])}, {'dog': array([1]), 'person': array([0])}, {'dog': array([0]), 'cow': array([1])}, {}, {'person': array([0])}, {'teddy bear': array([1]), 'dog': array([0])}, {'dog': array([0, 1])}]

# %% [markdown]
#  # <span style='color: #880088'>@@ 函數的通常使用方法 @@</span>
# ```python
# # 預先載入a組圖片
# db_a_get_ready()
#
# # 進入使用者輸入分析階段
# while (使用者是否載入新的b組圖片):
#     # 載入b組圖片
#     db_b_get_ready(image_path)
#
#     # 預先比對a組和b組的相似度
#     match_a_b()
#
#     # 得到比對相似度成功的一張圖片 or None
#     similar_img = final_compare()
#
#     # 判斷是否比對成功
#     if similar_img is None:
#     cv2.imshow(img) # 成功，印出比對成功的圖片
#     else:
#         print(‘比對失敗’)
# ```
